# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('data.csv')
df
# Out:
#    id gender    age  job
# 0   1      f     32  yes
# 1   2      m    18?  NaN
# 2   3     na     26   no
# 3   4      m    NaN  yes
# 4   5      1     26    0
# 5   6      f     23  NaN
# 6   7      m  'NaN'  yes

# %%
df.isnull()
# Out:
#       id  gender    age    job
# 0  False   False  False  False
# 1  False   False  False   True
# 2  False   False  False  False
# 3  False   False   True  False
# 4  False   False  False  False
# 5  False   False  False   True
# 6  False   False  False  False

# %%
df.isnull().sum()
# Out:
# id        0
# gender    0
# age       1
# job       2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 3

# %% [markdown]
# # Non standard type

# %%
df=pd.read_csv('data.csv',na_values=["'NaN'",'no'])
df
# Out:
#    id gender  age  job
# 0   1      f   32  yes
# 1   2      m  18?  NaN
# 2   3     na   26  NaN
# 3   4      m  NaN  yes
# 4   5      1   26    0
# 5   6      f   23  NaN
# 6   7      m  NaN  yes

# %% [markdown]
# # Unexpect types

# %%
i=0
for age in df['age']:
    try:
        int(age)
    except:
        df.loc[i,'age']=np.nan
        pass
    i+=1

# %%
df
# Out:
#    id gender  age  job
# 0   1      f   32  yes
# 1   2      m  NaN  NaN
# 2   3     na   26  NaN
# 3   4      m  NaN  yes
# 4   5      1   26    0
# 5   6      f   23  NaN
# 6   7      m  NaN  yes

# %%
df.loc[(df['gender']!='m')&(df['gender']!='f'),'gender']=np.nan

# %%
df
# Out:
#    id gender  age  job
# 0   1      f   32  yes
# 1   2      m  NaN  NaN
# 2   3    NaN   26  NaN
# 3   4      m  NaN  yes
# 4   5    NaN   26    0
# 5   6      f   23  NaN
# 6   7      m  NaN  yes

# %%
df.loc[(df['job']!='yes')&(df['job']!='no'),'job']=np.nan

# %%
df
# Out:
#    id gender  age  job
# 0   1      f   32  yes
# 1   2      m  NaN  NaN
# 2   3    NaN   26  NaN
# 3   4      m  NaN  yes
# 4   5    NaN   26  NaN
# 5   6      f   23  NaN
# 6   7      m  NaN  yes
