# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
airports=pd.read_csv('airports.csv')

# %%
airports.shape
# Out:
# (54364, 18)

# %%
airports.columns
# Out:
# Index(['id', 'ident', 'type', 'name', 'latitude_deg', 'longitude_deg',
#        'elevation_ft', 'continent', 'iso_country', 'iso_region',
#        'municipality', 'scheduled_service', 'gps_code', 'iata_code',
#        'local_code', 'home_link', 'wikipedia_link', 'keywords'],
#       dtype='object')

# %%
airports.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.949200    -151.695999         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# ...

# %%
airports.head(9)
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
# 5  322127  00AS  small_airport                      Fulton Airport
# 6    6527  00AZ  small_airport                      Cordes Airport
# 7    6528  00CA  small_airport             Goldstone /Gts/ Airport
# 8  324424  00CL  small_airport                 Williams Ag Airport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# ...

# %%
airports.tail()
# Out:
#            id    ident            type                       name  \
# 54359  317861     ZYYK  medium_airport      Yingkou Lanqi Airport
# 54360   32753     ZYYY  medium_airport    Shenyang Dongta Airport
# 54361   46378  ZZ-0001        heliport            Sealand Helipad
# 54362  307326  ZZ-0002   small_airport  Glorioso Islands Airstrip
# 54363  313629     ZZZZ   small_airport     Satsuma Iōjima Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 54359     40.542524     122.358600           0.0        AS          CN
# 54360     41.784401     123.496002           NaN        AS          CN
# 54361     51.894444       1.482500          40.0        EU          GB
# 54362    -11.584278      47.296389          11.0        AF          TF
# 54363     30.784722     130.270556         338.0        AS          JP
#
#       iso_region      municipality scheduled_service gps_code iata_code  \
# ...

# %%
airports.tail(-2)
# Out:
#            id    ident            type                                name  \
# 2        6524     00AK   small_airport                        Lowell Field
# 3        6525     00AL   small_airport                        Epps Airpark
# 4        6526     00AR          closed  Newport Hospital & Clinic Heliport
# 5      322127     00AS   small_airport                      Fulton Airport
# 6        6527     00AZ   small_airport                      Cordes Airport
# ...       ...      ...             ...                                 ...
# 54359  317861     ZYYK  medium_airport               Yingkou Lanqi Airport
# 54360   32753     ZYYY  medium_airport             Shenyang Dongta Airport
# 54361   46378  ZZ-0001        heliport                     Sealand Helipad
# 54362  307326  ZZ-0002   small_airport           Glorioso Islands Airstrip
# 54363  313629     ZZZZ   small_airport              Satsuma Iōjima Airport
#
# ...

# %%
airports[123:125]
# Out:
#         id ident           type              name  latitude_deg  \
# 123  45900  01WT       heliport  Odyssey Heliport     47.518178
# 124   6635  01WY  small_airport   Keyhole Airport     44.347198
#
#      longitude_deg  elevation_ft continent iso_country iso_region  \
# 123    -122.210908          20.0       NaN          US      US-WA
# 124    -104.810997        4250.0       NaN          US      US-WY
#
#     municipality scheduled_service gps_code iata_code local_code home_link  \
# 123       Renton                no     01WT       NaN       01WT       NaN
# 124    Moorcroft                no     01WY       NaN       01WY       NaN
#
#     wikipedia_link keywords
# 123            NaN      NaN
# 124            NaN      NaN

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54364 entries, 0 to 54363
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 54364 non-null  int64
#  1   ident              54364 non-null  object
#  2   type               54364 non-null  object
#  3   name               54364 non-null  object
#  4   latitude_deg       54364 non-null  float64
#  5   longitude_deg      54364 non-null  float64
#  6   elevation_ft       47478 non-null  float64
#  7   continent          27128 non-null  object
#  8   iso_country        54117 non-null  object
#  9   iso_region         54364 non-null  object
#  10  municipality       48793 non-null  object
#  11  scheduled_service  54364 non-null  object
#  12  gps_code           41057 non-null  object
#  13  iata_code          9166 non-null   object
#  14  local_code         28393 non-null  object
#  15  home_link          2910 non-null   object
# ...

# %%
airports.describe()
# Out:
#                   id  latitude_deg  longitude_deg  elevation_ft
# count   54364.000000  54364.000000   54364.000000  47478.000000
# mean    80227.547715     25.675663     -34.716785   1230.461540
# std    117751.159363     27.280617      79.928639   1584.327812
# min         2.000000    -90.000000    -179.876999  -1266.000000
# 25%     13710.750000      7.766667     -91.724573    205.000000
# 50%     27406.500000     36.583351     -71.929150    716.000000
# 75%     43507.250000     43.771632      15.125505   1486.000000
# max    328763.000000     82.750000     179.975700  22000.000000

# %%
airports["type"].unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
airports["type"].value_counts()
# Out:
# small_airport     33907
# heliport          11084
# medium_airport     4573
# closed             3156
# seaplane_base      1023
# large_airport       598
# balloonport          23
# Name: type, dtype: int64

# %%
airports[airports["type"]=='balloonport']
# Out:
#            id    ident         type  \
# 1324     7767     12JY  balloonport
# 1393     7829      13M  balloonport
# 2874     9213     28NC  balloonport
# 3178    45530     2JY7  balloonport
# 3895    10140     35JY  balloonport
# 5522    11644     4OH6  balloonport
# 5972    12057     55NJ  balloonport
# 6130    46296     59ID  balloonport
# 6362    12432     5KS0  balloonport
# 10851   38811  AR-0136  balloonport
# 12044  324445  BE-0012  balloonport
# 15382   16882     CO28  balloonport
# 17155  323838  DE-0351  balloonport
# 21043  322152  FR-0354  balloonport
# 24870   18263     JY03  balloonport
# 24899   18292     JY33  balloonport
# 24907   18299     JY42  balloonport
# 30317  314582      KZR  balloonport
# 32431   21769     MA26  balloonport
# 36044  326206  NO-0072  balloonport
# 36337   45548     NY80  balloonport
# 38957   24352     RI16  balloonport
# 49960   25392     VA60  balloonport
#
#                                                     name  latitude_deg  \
# ...

# %%
airports[airports["type"]=='balloonport']['continent']
# Out:
# 1324     NaN
# 1393     NaN
# 2874     NaN
# 3178     NaN
# 3895     NaN
# 5522     NaN
# 5972     NaN
# 6130     NaN
# 6362     NaN
# 10851     SA
# 12044     EU
# 15382    NaN
# 17155     EU
# 21043     EU
# 24870    NaN
# 24899    NaN
# 24907    NaN
# 30317     AS
# 32431    NaN
# 36044     EU
# 36337    NaN
# 38957    NaN
# 49960    NaN
# Name: continent, dtype: object

# %%
airports['iso_country'][pd.isnull(airports['continent'])]
# Out:
# 0        US
# 1        US
# 2        US
# 3        US
# 4        US
#          ..
# 53869    US
# 53870    US
# 53871    US
# 53872    US
# 54187    US
# Name: iso_country, Length: 27236, dtype: object

# %%
airports.loc[pd.isnull(airports['continent']),'continent']='NA'

# %%
airports['type'].value_counts().plot()
plt.show()

# %%
airports['type'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
airports['type'].value_counts().plot(kind='bar',figsize=(8,8))
plt.xlabel('count')
plt.ylabel('type')
plt.show()

# %%
airports['type'].value_counts().plot(kind='pie',figsize=(8,8))
plt.show()

# %%
airports.groupby(['continent','type']).size()
# Out:
# continent  type
# AF         closed               70
#            heliport              9
#            large_airport        32
#            medium_airport      463
#            seaplane_base         1
#            small_airport      2759
# AN         closed                2
#            medium_airport        4
#            small_airport        21
# AS         balloonport           1
#            closed              252
#            heliport           1618
#            large_airport       155
#            medium_airport     1204
#            seaplane_base        22
#            small_airport      2079
# EU         balloonport           4
#            closed              731
#            heliport            990
#            large_airport       166
#            medium_airport      938
#            seaplane_base        33
#            small_airport      4859
# NA         NA                27236
# OC         closed              132
#            heliport            246
# ...

# %%
airports.groupby(['continent','type']).size().unstack()
# Out:
# type            NA  balloonport  closed  heliport  large_airport  \
# continent
# AF             NaN          NaN    70.0       9.0           32.0
# AN             NaN          NaN     2.0       NaN            NaN
# AS             NaN          1.0   252.0    1618.0          155.0
# EU             NaN          4.0   731.0     990.0          166.0
# NA         27236.0          NaN     NaN       NaN            NaN
# OC             NaN          NaN   132.0     246.0           14.0
# SA             NaN          1.0   192.0    1324.0           20.0
#
# type       medium_airport  seaplane_base  small_airport
# continent
# AF                  463.0            1.0         2759.0
# AN                    4.0            NaN           21.0
# AS                 1204.0           22.0         2079.0
# EU                  938.0           33.0         4859.0
# NA                    NaN            NaN            NaN
# OC                  320.0           11.0         2344.0
# ...

# %%
airports.groupby(['continent', 'type']).size().unstack().plot(kind='bar',figsize=(8,8))
# Out:
# <Axes: xlabel='continent'>

# %%
airports.groupby(['continent', 'type']).size().unstack().plot(kind='bar',figsize=(8,8),stacked=True)
# Out:
# <Axes: xlabel='continent'>
