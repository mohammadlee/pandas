# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv('./csv/countries.csv')
# Out:
#          id code                           name continent  \
# 0    302672   AD                        Andorra        EU
# 1    302618   AE           United Arab Emirates        AS
# 2    302619   AF                    Afghanistan        AS
# 3    302722   AG            Antigua and Barbuda       NaN
# 4    302723   AI                       Anguilla       NaN
# ..      ...  ...                            ...       ...
# 243  302609   YT                        Mayotte        AF
# 244  302610   ZA                   South Africa        AF
# 245  302611   ZM                         Zambia        AF
# 246  302612   ZW                       Zimbabwe        AF
# 247  302613   ZZ  Unknown or unassigned country        AF
#
#                                         wikipedia_link  \
# 0                https://en.wikipedia.org/wiki/Andorra
# 1    https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2            https://en.wikipedia.org/wiki/Afghanistan
# ...

# %%
pd.read_csv('./csv/countries.csv',header=1)
# Out:
#      302672  AD                        Andorra   EU  \
# 0    302618  AE           United Arab Emirates   AS
# 1    302619  AF                    Afghanistan   AS
# 2    302722  AG            Antigua and Barbuda  NaN
# 3    302723  AI                       Anguilla  NaN
# 4    302673  AL                        Albania   EU
# ..      ...  ..                            ...  ...
# 242  302609  YT                        Mayotte   AF
# 243  302610  ZA                   South Africa   AF
# 244  302611  ZM                         Zambia   AF
# 245  302612  ZW                       Zimbabwe   AF
# 246  302613  ZZ  Unknown or unassigned country   AF
#
#                  https://en.wikipedia.org/wiki/Andorra  \
# 0    https://en.wikipedia.org/wiki/United_Arab_Emir...
# 1            https://en.wikipedia.org/wiki/Afghanistan
# 2    https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# 3               https://en.wikipedia.org/wiki/Anguilla
# 4                https://en.wikipedia.org/wiki/Albania
# ...

# %%
pd.read_csv('./csv/countries.csv',header=1,sep=',')
# Out:
#      302672  AD                        Andorra   EU  \
# 0    302618  AE           United Arab Emirates   AS
# 1    302619  AF                    Afghanistan   AS
# 2    302722  AG            Antigua and Barbuda  NaN
# 3    302723  AI                       Anguilla  NaN
# 4    302673  AL                        Albania   EU
# ..      ...  ..                            ...  ...
# 242  302609  YT                        Mayotte   AF
# 243  302610  ZA                   South Africa   AF
# 244  302611  ZM                         Zambia   AF
# 245  302612  ZW                       Zimbabwe   AF
# 246  302613  ZZ  Unknown or unassigned country   AF
#
#                  https://en.wikipedia.org/wiki/Andorra  \
# 0    https://en.wikipedia.org/wiki/United_Arab_Emir...
# 1            https://en.wikipedia.org/wiki/Afghanistan
# 2    https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# 3               https://en.wikipedia.org/wiki/Anguilla
# 4                https://en.wikipedia.org/wiki/Albania
# ...

# %%
pd.read_csv('./csv/countries.csv',header=0,sep=',',names=['id','iso country','country','continent','website','note'])
# Out:
#          id iso country                        country continent  \
# 0    302672          AD                        Andorra        EU
# 1    302618          AE           United Arab Emirates        AS
# 2    302619          AF                    Afghanistan        AS
# 3    302722          AG            Antigua and Barbuda       NaN
# 4    302723          AI                       Anguilla       NaN
# ..      ...         ...                            ...       ...
# 243  302609          YT                        Mayotte        AF
# 244  302610          ZA                   South Africa        AF
# 245  302611          ZM                         Zambia        AF
# 246  302612          ZW                       Zimbabwe        AF
# 247  302613          ZZ  Unknown or unassigned country        AF
#
#                                                website  \
# 0                https://en.wikipedia.org/wiki/Andorra
# 1    https://en.wikipedia.org/wiki/United_Arab_Emir...
# ...

# %%
pd.read_csv('./csv/countries.csv',header=0,sep=',',names=['id','iso country','country','continent','website','note'],encoding='utf_8')
# Out:
#          id iso country                        country continent  \
# 0    302672          AD                        Andorra        EU
# 1    302618          AE           United Arab Emirates        AS
# 2    302619          AF                    Afghanistan        AS
# 3    302722          AG            Antigua and Barbuda       NaN
# 4    302723          AI                       Anguilla       NaN
# ..      ...         ...                            ...       ...
# 243  302609          YT                        Mayotte        AF
# 244  302610          ZA                   South Africa        AF
# 245  302611          ZM                         Zambia        AF
# 246  302612          ZW                       Zimbabwe        AF
# 247  302613          ZZ  Unknown or unassigned country        AF
#
#                                                website  \
# 0                https://en.wikipedia.org/wiki/Andorra
# 1    https://en.wikipedia.org/wiki/United_Arab_Emir...
# ...

# %%
coun=pd.read_csv('./csv/countries.csv',header=0,sep=',',names=['id','iso country','country','continent','website','note'],encoding='utf_8')

# %%
coun.to_csv('countries2.csv',index=False)

# %%
coun[0:-1]
# Out:
#          id iso country               country continent  \
# 0    302672          AD               Andorra        EU
# 1    302618          AE  United Arab Emirates        AS
# 2    302619          AF           Afghanistan        AS
# 3    302722          AG   Antigua and Barbuda       NaN
# 4    302723          AI              Anguilla       NaN
# ..      ...         ...                   ...       ...
# 242  302671          YE                 Yemen        AS
# 243  302609          YT               Mayotte        AF
# 244  302610          ZA          South Africa        AF
# 245  302611          ZM                Zambia        AF
# 246  302612          ZW              Zimbabwe        AF
#
#                                                website  \
# 0                https://en.wikipedia.org/wiki/Andorra
# 1    https://en.wikipedia.org/wiki/United_Arab_Emir...
# 2            https://en.wikipedia.org/wiki/Afghanistan
# 3    https://en.wikipedia.org/wiki/Antigua_and_Barbuda
# ...

# %%
coun[105:108]
# Out:
#          id iso country  country continent  \
# 105  302637          IR     Iran        AS
# 106  302696          IS  Iceland        EU
# 107  302697          IT    Italy        EU
#
#                                    website                note
# 105     https://en.wikipedia.org/wiki/Iran   فرودگاه های ایران
# 106  https://en.wikipedia.org/wiki/Iceland  Icelandic airports
# 107    https://en.wikipedia.org/wiki/Italy  Aeroporti d'Italia
